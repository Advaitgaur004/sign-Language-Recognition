# %% [markdown]
# <a href="https://colab.research.google.com/github/Advaitgaur004/sign-Language-Recognition/blob/main/yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt comet_ml

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-195-g7a70d09 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.4/78.2 GB disk)

# %%
# !unzip -q ../test.zip -d ../
# !unzip -q ../train.zip -d ../
# !unzip -q ../valid.zip -d ../

# %%
# !python train.py --img 640 --batch 20 --epochs 50 --data custom_dataset.yaml --weights yolov5s.pt --cache
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../test/images/
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../F.jpeg
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
import cv2
import matplotlib.pyplot as plt

img=cv2.imread('/content/test/images/A22_jpg.rf.f02ad8558ce1c88213b4f83c0bc66bc8.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img=cv2.imread('/content/yolov5/runs/detect/exp/A22_jpg.rf.f02ad8558ce1c88213b4f83c0bc66bc8.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

Without_Annotation = mpimg.imread('/content/F.jpeg')
With_Annotation = mpimg.imread('/content/yolov5/runs/detect/exp2/F.jpeg')

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].imshow(Without_Annotation)
axs[0].set_title('Without_Annotation')

axs[1].imshow(With_Annotation)
axs[1].set_title('With_Annotation')

plt.axis('off')
plt.show()

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../test_case_1.jpeg
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../test_case_2.jpeg
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

Without_Annotation = mpimg.imread('/content/test_case_1.jpeg')
With_Annotation = mpimg.imread('/content/yolov5/runs/detect/exp3/test_case_1.jpeg')



fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].imshow(Without_Annotation)
axs[0].set_title('Without_Annotation')

axs[1].imshow(With_Annotation)
axs[1].set_title('With_Annotation')
plt.axis('off')
plt.show()

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../test_case_3.jpeg
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

Without_Annotation = mpimg.imread('/content/test_case_3.jpeg')
With_Annotation = mpimg.imread('/content/yolov5/runs/detect/exp5/test_case_3.jpeg')



fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].imshow(Without_Annotation)
axs[0].set_title('Without_Annotation')

axs[1].imshow(With_Annotation)
axs[1].set_title('With_Annotation')
plt.axis('off')
plt.show()

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path = 'runs/train/exp/weights/best.pt' ,force_reload=True)
